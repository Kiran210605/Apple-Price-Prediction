# %% [markdown]
# <a href="https://colab.research.google.com/github/Kiran210605/Apple-Price-Prediction/blob/main/Apple_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
page=requests.get("https://www.timesofsports.com/cricket/indian-players-salary/").text
soup=BeautifulSoup(page,'html.parser')
artist=soup.find_all('a')

# %%
for artists in artist:
  names=artists.contents[0]
  fulllink=artists.get('herf')
  print(names)
  print(fulllink)
# Out:
# None
#
#
# None
#
#
# None
# <i class="td-icon-close-mobile"></i>
# None
# ICC Rankings
# None
# Men’s Ranking
# None
# ODI Team Rankings
# None
# T20i Team Rankings
# None
# Test Team Rankings
# None
# ODI Players Rankings
# None
# T20i Players Rankings
# None
# Test Players Rankings
# None
# Women’s Ranking
# None
# Women’s ODI Team Rankings
# None
# Women’s T20I Team Rankings
# None
# Women’s ODI Players Rankings
# None
# Women’s T20I Players Rankings
# None
# Biography
# None
# Cricket Players
# None
# Football Players
# None
# IPL 2023
# None
# Chennai Super Kings
# None
# Mumbai Indians
# None
# Royal Challengers Bangalore
# None
# Kolkata Knight Riders
# None
# Delhi Capitals
# None
# Gujarat Titans
# None
# Lucknow Super Giants
# None
# Punjab Kings
# None
# Rajasthan Royals
# None
# Sunrisers Hyderabad
# None
# Cricket Leagues
# None
# BBL
# None
# CPL
# None
# Desert Cup
# None
# ILT20
# None
# LPL
# None
# Super Smash
# None
# T10 League
# None
# PSL
# None
# The Hundred
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")
print(msft)
"""
returns
<yfinance.Ticker object at 0x1a1715e898>
"""

# get stock info
msft.info

"""
returns:
{
 'quoteType': 'EQUITY',
 'quoteSourceName': 'Nasdaq Real Time Price',
 'currency': 'USD',
 'shortName': 'Microsoft Corporation',
 'exchangeTimezoneName': 'America/New_York',
  ...
 'symbol': 'MSFT'
}
"""

# get historical market data
msft.history(period="max")
"""
returns:
              Open    High    Low    Close      Volume  Dividends  Splits
Date
1986-03-13    0.06    0.07    0.06    0.07  1031788800        0.0     0.0
1986-03-14    0.07    0.07    0.07    0.07   308160000        0.0     0.0
...
2019-04-15  120.94  121.58  120.57  121.05    15792600        0.0     0.0
2019-04-16  121.64  121.65  120.10  120.77    14059700        0.0     0.0
"""

# show actions (dividends, splits)
msft.actions
"""
returns:
            Dividends  Splits
Date
1987-09-21       0.00     2.0
1990-04-16       0.00     2.0
...
2018-11-14       0.46     0.0
2019-02-20       0.46     0.0
"""

# show dividends
msft.dividends
"""
returns:
Date
2003-02-19    0.08
2003-10-15    0.16
...
2018-11-14    0.46
2019-02-20    0.46
"""

# show splits
msft.splits
"""
returns:
Date
1987-09-21    2.0
1990-04-16    2.0
...
1999-03-29    2.0
2003-02-18    2.0
"""
# Out:
# yfinance.Ticker object <MSFT>
# '\nreturns:\nDate\n1987-09-21    2.0\n1990-04-16    2.0\n...\n1999-03-29    2.0\n2003-02-18    2.0\n'

# %%
import yfinance as yf
data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30",
                   group_by="ticker")
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
from pandas_datareader import data as pdr

import yfinance as yf
yf.pdr_override() # <== that's all it takes :-)

# download dataframe using pandas_datareader
data = pdr.get_data_yahoo("SPY", start="2017-01-01", end="2017-04-30")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
apple = yf.Ticker("AAPL")

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/apple.json
# Out:
# --2023-10-19 12:23:55--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/data/apple.json
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5699 (5.6K) [application/json]
# Saving to: ‘apple.json’
#
# apple.json          100%[===================>]   5.57K  --.-KB/s    in 0s
#
# 2023-10-19 12:23:55 (1.76 GB/s) - ‘apple.json’ saved [5699/5699]

# %%
import json
with open('apple.json') as json_file:
    apple_info = json.load(json_file)
    # Print the type of data variable
    #print("Type:", type(apple_info))
apple_info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
apple_share_price_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1980-12-12 00:00:00-05:00  0.099449  0.099882  0.099449  0.099449  469033600
# 1980-12-15 00:00:00-05:00  0.094694  0.094694  0.094261  0.094261  175884800
# 1980-12-16 00:00:00-05:00  0.087775  0.087775  0.087343  0.087343  105728000
# 1980-12-17 00:00:00-05:00  0.089504  0.089937  0.089504  0.089504   86441600
# 1980-12-18 00:00:00-05:00  0.092099  0.092532  0.092099  0.092099   73449600
#
#                            Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00        0.0           0.0
# 1980-12-15 00:00:00-05:00        0.0           0.0
# 1980-12-16 00:00:00-05:00        0.0           0.0
# 1980-12-17 00:00:00-05:00        0.0           0.0
# 1980-12-18 00:00:00-05:00        0.0           0.0

# %%
apple_share_price_data.reset_index(inplace=True)

# %%
apple_share_price_data.plot(x="Date", y="Open")
# Out:
# <Axes: xlabel='Date'>

# %%
apple.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2022-08-05 00:00:00-04:00    0.230000
# 2022-11-04 00:00:00-04:00    0.230000
# 2023-02-10 00:00:00-05:00    0.230000
# 2023-05-12 00:00:00-04:00    0.240000
# 2023-08-11 00:00:00-04:00    0.240000
# Name: Dividends, Length: 80, dtype: float64

# %%
apple.dividends.plot()
# Out:
# <Axes: xlabel='Date'>
